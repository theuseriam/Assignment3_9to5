-- %% [markdown]
-- # <span style="font-size: 20pt; font-family: Montserrat, sans-serif; color: rgb(92, 148, 206); background-color: rgb(255, 255, 255); font-weight: 700; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Graded Assignment 3: 9 to 5</span>
--
--
--
-- <span style="font-size: 10pt; font-family: &quot;Times New Roman&quot;; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Time to show off your SQL skills! For each question, copy the SQL query you used and make note of the answer.</span>
--
--
--
-- ## <span style="font-size: 12pt; font-family: Montserrat, sans-serif; color: rgb(53, 74, 95); background-color: rgb(255, 255, 255); font-weight: 700; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">The Dataset</span>
--
-- <span style="font-size: 10pt; font-family: &quot;Times New Roman&quot;; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">For this assignment, you will be using the Bureau of Labor Statistics (BLS) Current Employment Survey (CES) results which can be found on</span> [<span style="font-size: 10pt; font-family: &quot;Times New Roman&quot;; color: rgb(17, 85, 204); background-color: rgb(255, 255, 255); font-variant-east-asian: normal; text-decoration-line: underline; vertical-align: baseline; white-space: pre-wrap;">Kaggle</span>](https://www.kaggle.com/bls/employment)<span style="font-size: 10pt; font-family: &quot;Times New Roman&quot;; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">.</span>
--
--
--
-- ## <span style="font-size: 12pt; font-family: Montserrat, sans-serif; color: rgb(53, 74, 95); background-color: rgb(255, 255, 255); font-weight: 700; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Business Issue</span>
--
-- <span style="font-size: 10pt; font-family: &quot;Times New Roman&quot;; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">You are working for the Bureau of Labor Statistics with the United States government and have been approached by your boss with an important meeting request. You have been asked by your supervisor to meet with Dolly Parton whose nonprofit is looking to shed light on the state of employment in the United States. As part of the 9 to 5 project, their research is focused on production and nonsupervisory employees and how those employees fare compared to all employees in the United States. While the data the BLS collects from the CES is publicly available, Dolly Parton and her colleagues need your assistance navigating the thousands of rows in each table in LaborStatisticsDB.</span>
--
--
--
-- ## <span style="font-size: 12pt; font-family: Montserrat, sans-serif; color: rgb(53, 74, 95); background-color: rgb(255, 255, 255); font-weight: 700; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">About the Dataset</span>
--
-- <span style="font-size: 10pt; font-family: &quot;Times New Roman&quot;; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">This dataset comes directly from the Bureau of Labor Statistics’ Current Employment Survey (CES). Here are some things you need to know:</span>
--
-- 1. <span style="font-size: 10pt; background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">The industry table contains an NAICS code. This is different from the industry code. NAICS stands for North American Industry Classification System.</span>
--
-- 2. <span style="font-size: 10pt; background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Series ID is composed of multiple different codes. CES stands for Current Employment Survey, the name of the survey which collected the data. The industry code as specified by the BLS and the data type code as specified in the datatype table.</span>
--
--
--
--
-- ## <span style="font-size: 12pt; font-family: Montserrat, sans-serif; color: rgb(53, 74, 95); background-color: rgb(255, 255, 255); font-weight: 700; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Set Up</span>
--
-- <span style="font-size: 10pt; font-family: &quot;Times New Roman&quot;; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">To connect to the database, use the same connection info used during the SQL lessons.&nbsp;</span>
--
-- <span style="font-size: 10pt; font-family: &quot;Times New Roman&quot;; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">For the assignment, we will be using the LaborStatisticsDB database.</span>
--
--
--
-- ## <span style="font-size: 12pt; font-family: Montserrat, sans-serif; color: rgb(53, 74, 95); background-color: rgb(255, 255, 255); font-weight: 700; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Database Exploration</span>
--
-- <span style="font-size: 10pt; font-family: &quot;Times New Roman&quot;; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">To start with, let’s get to know the database further.</span>
--
-- 1. <span style="background-color: rgb(255, 255, 255); color: rgb(102, 102, 102); font-family: &quot;Times New Roman&quot;; font-size: 10pt; white-space: pre-wrap;">Use this space to make note of each table in the database, the columns within each table, each column’s data type, and how the tables are connected. You can write this down or draw a diagram. Whatever method helps you get an understanding of what is going on with LaborStatisticsDB.</span>

-- %% [markdown]
-- To add a photo, diagram or document to your file, drop the file into the folder that holds this notebook.  Use the the link button to the right of the  \</\> symbol in the gray part of this cell, the link is just the name of your file.

-- %%
PRINT 'Github test';
-- Out:
-- Github test
-- Total execution time: 00:00:00.031

-- %% [markdown]
-- 2. <span style="background-color: rgb(255, 255, 255); color: rgb(102, 102, 102); font-family: Arvo, serif; font-size: 10pt; white-space: pre-wrap;">What is the datatype for women employees?</span>

-- %%
--The data type code for women is 10
SELECT data_type_code
FROM datatype
WHERE data_type_text = 'women employees'
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.041
-- <table><tr><th>data_type_code</th></tr><tr><td>10</td></tr></table>

-- %% [markdown]
-- 3. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">What is the series id for&nbsp; women employees in the commercial banking industry in the financial activities supersector?</span>

-- %%
SELECT industry_code, industry_name
FROM industry
WHERE industry_name LIKE 'commercial ba%';
--55522110
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.048
-- <table><tr><th>industry_code</th><th>industry_name</th></tr><tr><td>55522110</td><td>Commercial banking</td></tr></table>

-- %% [markdown]
-- ## <span style="font-size: 12pt; font-family: Montserrat, sans-serif; color: rgb(53, 74, 95); background-color: rgb(255, 255, 255); font-weight: 700; font-variant-numeric: normal; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Join in on the Fun</span>
--
-- <span style="font-size: 10pt; font-family: Arvo, serif; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-numeric: normal; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Time to start joining! You can choose the type of join you use, just make sure to make a&nbsp; note!</span>
--
-- 1. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">Join&nbsp; annual_2016 with series on series_id. We only want the data in the annual_2016 table to be included in the result.</span>

-- %%
--I chose intersect because it only shows rows that match or are present on both tables
SELECT annual_2016.series_id AS annual2016ID
FROM annual_2016
INTERSECT
SELECT series.series_id
FROM series
-- Out:
-- (13348 rows affected)
-- Displaying Top 5000 rows.
-- Total execution time: 00:00:00.370
-- <table><tr><th>annual2016ID</th></tr><tr><td>CEU6562111132</td></tr><tr><td>CEU6562400034</td></tr><tr><td>CEU4348540081</td></tr><tr><td>CEU6054181011</td></tr><tr><td>CEU2023814008</td></tr><tr><td>CEU4142349057</td></tr><tr><td>CEU4422111210</td></tr><tr><td>CEU6562400013</td></tr><tr><td>CEU3133400013</td></tr><tr><td>CEU3232560016</td></tr><tr><td>CEU3133390010</td></tr><tr><td>CEU5552210001</td></tr><tr><td>CEU8081399082</td></tr><tr><td>CEU4244420034</td></tr><tr><td>CEU5552232012</td></tr><tr><td>CEU3231100058</td></tr><tr><td>CEU6054119057</td></tr><tr><td>CEU6054151157</td></tr><tr><td>CEU6056162002</td></tr><tr><td>CEU3132199057</td></tr><tr><td>CEU4142394017</td></tr><tr><td>CEU6562190006</td></tr><tr><td>CEU3133640031</td></tr><tr><td>CEU5553210012</td></tr><tr><td>CEU6054119013</td></tr><tr><td>CEU3232610057</td></tr><tr><td>CEU7072110010</td></tr><tr><td>CEU6056174030</td></tr><tr><td>CEU6562230056</td></tr><tr><td>CEU4142394013</td></tr><tr><td>CEU5552229210</td></tr><tr><td>CEU3133360032</td></tr><tr><td>CEU4244400031</td></tr><tr><td>CEU5553220016</td></tr><tr><td>CEU6562200002</td></tr><tr><td>CEU6056100001</td></tr><tr><td>CEU4142369001</td></tr><tr><td>CEU4142372081</td></tr><tr><td>CEU4244611003</td></tr><tr><td>CEU8081200081</td></tr><tr><td>CEU6562411002</td></tr><tr><td>CEU4348410008</td></tr><tr><td>CEU6056133003</td></tr><tr><td>CEU3133351901</td></tr><tr><td>CEU6056191081</td></tr><tr><td>CEU3133637009</td></tr><tr><td>CEU5051120081</td></tr><tr><td>CEU6054160034</td></tr><tr><td>CEU4244131082</td></tr><tr><td>CEU3133232212</td></tr><tr><td>CEU3231140031</td></tr><tr><td>CEU3132199004</td></tr><tr><td>CEU6562199032</td></tr><tr><td>CEU4244120031</td></tr><tr><td>CEU2023891056</td></tr><tr><td>CEU4348830008</td></tr><tr><td>CEU3231100082</td></tr><tr><td>CEU6054172057</td></tr><tr><td>CEU6054132006</td></tr><tr><td>CEU7072233002</td></tr><tr><td>CEU5500000010</td></tr><tr><td>CEU6056220007</td></tr><tr><td>CEU5552229134</td></tr><tr><td>CEU8081230001</td></tr><tr><td>CEU3232615015</td></tr><tr><td>CEU7071219001</td></tr><tr><td>CEU6056000013</td></tr><tr><td>CEU6054143010</td></tr><tr><td>CEU2023610082</td></tr><tr><td>CEU4142369006</td></tr><tr><td>CEU3231161310</td></tr><tr><td>CEU3133330035</td></tr><tr><td>CEU6054194034</td></tr><tr><td>CEU6056170031</td></tr><tr><td>CEU7072100008</td></tr><tr><td>CEU3231520010</td></tr><tr><td>CEU3133440035</td></tr><tr><td>CEU6562210032</td></tr><tr><td>CEU4142385012</td></tr><tr><td>CEU3231100033</td></tr><tr><td>CEU6054110056</td></tr><tr><td>CEU7072200011</td></tr><tr><td>CEU3133272056</td></tr><tr><td>CEU6056191030</td></tr><tr><td>CEU6562150010</td></tr><tr><td>CEU3133440033</td></tr><tr><td>CEU6562150032</td></tr><tr><td>CEU4245200035</td></tr><tr><td>CEU6056191012</td></tr><tr><td>CEU4348500017</td></tr><tr><td>CEU4142371017</td></tr><tr><td>CEU5051112056</td></tr><tr><td>CEU4244410008</td></tr><tr><td>CEU5553230017</td></tr><tr><td>CEU6054120002</td></tr><tr><td>CEU6056110011</td></tr><tr><td>CEU4142470016</td></tr><tr><td>CEU5051500016</td></tr><tr><td>CEU6054150031</td></tr><tr><td>CEU8081221003</td></tr><tr><td>CEU3231181356</td></tr><tr><td>CEU4245420010</td></tr><tr><td>CEU6054000056</td></tr><tr><td>CEU1021220057</td></tr><tr><td>CEU4245110035</td></tr><tr><td>CEU4245111081</td></tr><tr><td>CEU6056161016</td></tr><tr><td>CEU7071390057</td></tr><tr><td>CEU3133231202</td></tr><tr><td>CEU3133911358</td></tr><tr><td>CEU4142385016</td></tr><tr><td>CEU5051110002</td></tr><tr><td>CEU3133631034</td></tr><tr><td>CEU4245390031</td></tr><tr><td>CEU3231190017</td></tr><tr><td>CEU4422000017</td></tr><tr><td>CEU5051720057</td></tr><tr><td>CEU5552412010</td></tr><tr><td>CEU6054119107</td></tr><tr><td>CEU7072240034</td></tr><tr><td>CEU8081200031</td></tr><tr><td>CEU3133281309</td></tr><tr><td>CEU3133711032</td></tr><tr><td>CEU2023730006</td></tr><tr><td>CEU3231161509</td></tr><tr><td>CEU3232300081</td></tr><tr><td>CEU3231140002</td></tr><tr><td>CEU4348420003</td> ...

-- %% [markdown]
-- 2. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">Join series and datatype on data_type_code</span>

-- %%
-- I am using Union because I don't want to include duplicates
SELECT data_type_code AS dtcode
FROM series
UNION
SELECT data_type_code
FROM datatype
-- Out:
-- (45 rows affected)
-- Total execution time: 00:00:00.128
-- <table><tr><th>dtcode</th></tr><tr><td>38</td></tr><tr><td>39</td></tr><tr><td>86</td></tr><tr><td>87</td></tr><tr><td>88</td></tr><tr><td>89</td></tr><tr><td>98</td></tr><tr><td>99</td></tr><tr><td>26</td></tr><tr><td>23</td></tr><tr><td>6</td></tr><tr><td>3</td></tr><tr><td>15</td></tr><tr><td>12</td></tr><tr><td>9</td></tr><tr><td>35</td></tr><tr><td>32</td></tr><tr><td>58</td></tr><tr><td>21</td></tr><tr><td>81</td></tr><tr><td>1</td></tr><tr><td>30</td></tr><tr><td>10</td></tr><tr><td>24</td></tr><tr><td>7</td></tr><tr><td>4</td></tr><tr><td>13</td></tr><tr><td>56</td></tr><tr><td>36</td></tr><tr><td>33</td></tr><tr><td>16</td></tr><tr><td>25</td></tr><tr><td>22</td></tr><tr><td>82</td></tr><tr><td>19</td></tr><tr><td>2</td></tr><tr><td>31</td></tr><tr><td>11</td></tr><tr><td>8</td></tr><tr><td>57</td></tr><tr><td>37</td></tr><tr><td>83</td></tr><tr><td>20</td></tr><tr><td>34</td></tr><tr><td>17</td></tr></table>

-- %% [markdown]
-- 3. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">Join series and industry on industry_code</span>

-- %%
-- I am using union to join in order to eliminate duplcates
SELECT industry_code AS icode
FROM series
UNION
SELECT industry_code
FROM industry
-- Out:
-- (915 rows affected)
-- Total execution time: 00:00:00.106
-- <table><tr><th>icode</th></tr><tr><td>0</td></tr><tr><td>31337215</td></tr><tr><td>32311811</td></tr><tr><td>70711219</td></tr><tr><td>32329100</td></tr><tr><td>5000000</td></tr><tr><td>31333920</td></tr><tr><td>65611500</td></tr><tr><td>20237100</td></tr><tr><td>31321918</td></tr><tr><td>42445110</td></tr><tr><td>55523900</td></tr><tr><td>90922920</td></tr><tr><td>10000000</td></tr><tr><td>43484120</td></tr><tr><td>55532290</td></tr><tr><td>42441320</td></tr><tr><td>60541513</td></tr><tr><td>60541519</td></tr><tr><td>70713950</td></tr><tr><td>90932999</td></tr><tr><td>42452111</td></tr><tr><td>60541613</td></tr><tr><td>60561510</td></tr><tr><td>31333519</td></tr><tr><td>60561410</td></tr><tr><td>65623210</td></tr><tr><td>20000000</td></tr><tr><td>42452990</td></tr><tr><td>31321214</td></tr><tr><td>31332323</td></tr><tr><td>41423850</td></tr><tr><td>55532110</td></tr><tr><td>60541310</td></tr><tr><td>60561610</td></tr><tr><td>65611600</td></tr><tr><td>20237200</td></tr><tr><td>31333511</td></tr><tr><td>31336413</td></tr><tr><td>32329000</td></tr><tr><td>42442210</td></tr><tr><td>55533000</td></tr><tr><td>70713100</td></tr><tr><td>80813400</td></tr><tr><td>41424800</td></tr><tr><td>43484220</td></tr><tr><td>50512130</td></tr><tr><td>65611400</td></tr><tr><td>20237000</td></tr><tr><td>30000000</td></tr><tr><td>41424700</td></tr><tr><td>43488110</td></tr><tr><td>31333110</td></tr><tr><td>31336110</td></tr><tr><td>31337100</td></tr><tr><td>41423420</td></tr><tr><td>41424600</td></tr><tr><td>43492000</td></tr><tr><td>31337000</td></tr><tr><td>41423320</td></tr><tr><td>43488900</td></tr><tr><td>10212300</td></tr><tr><td>31327900</td></tr><tr><td>31336900</td></tr><tr><td>31339900</td></tr><tr><td>41423220</td></tr><tr><td>65620001</td></tr><tr><td>70713990</td></tr><tr><td>70722400</td></tr><tr><td>31332721</td></tr><tr><td>32311230</td></tr><tr><td>40000000</td></tr><tr><td>41423120</td></tr><tr><td>42446000</td></tr><tr><td>43484200</td></tr><tr><td>50511200</td></tr><tr><td>65611700</td></tr><tr><td>70721120</td></tr><tr><td>80812112</td></tr><tr><td>31332200</td></tr><tr><td>31336350</td></tr><tr><td>60561450</td></tr><tr><td>31331510</td></tr><tr><td>65621493</td></tr><tr><td>90919110</td></tr><tr><td>31332320</td></tr><tr><td>31332910</td></tr><tr><td>60561330</td></tr><tr><td>60561613</td></tr><tr><td>70710000</td></tr><tr><td>70713910</td></tr><tr><td>50000000</td></tr><tr><td>80811190</td></tr><tr><td>55531311</td></tr><tr><td>55000000</td></tr><tr><td>70713930</td></tr><tr><td>31332300</td></tr><tr><td>32311900</td></tr><tr><td>60000000</td></tr><tr><td>80811110</td></tr><tr><td>31335311</td></tr><tr><td>43484100</td></tr><tr><td>80812000</td></tr><tr><td>20238302</td></tr><tr><td>31336330</td></tr><tr><td>41423400</td></tr><tr><td>41423990</td></tr><tr><td>65000000</td></tr><tr><td>65621999</td></tr><tr><td>20238002</td></tr><tr><td>32322130</td></tr><tr><td>41423200</td></tr><tr><td>50515110</td></tr><tr><td>55522300</td></tr><tr><td>65611620</td></tr><tr><td>70000000</td></tr><tr><td>41423100</td></tr><tr><td>55522200</td></tr><tr><td>70721100</td></tr><tr><td>20237120</td></tr><tr><td>42445290</td></tr><tr><td>55522100</td></tr><tr><td>65611420</td></tr><tr><td>65621991</td></tr><tr><td>70721000</td></tr><tr><td>20238202</td></tr><tr><td>31332400</td></tr><tr><td>31332990</td></tr><tr><td>32311410</td></tr><tr><td>55522000</td></tr><tr><td>55532230</td></tr><tr><td>90932000</td></tr><tr><td>20238102</td></tr><tr><td>31337120</td></tr><tr><td>42443000</td></tr><tr><td>43481200</td></tr><tr><td>80000000</td></tr><tr><td>42445230</td></tr><tr><td>55522120</td></tr><tr><td>10212320</td></tr><tr><td>31334510</td></tr><tr><td>31339920</td></tr><tr><td>60541610</td></tr><tr><td>80813311</td></tr><tr><td>32325900</td></tr><tr><td>41423300</td></tr><tr><td>31337212</td></tr><tr><td>32322219</td></tr><tr><td>55524298</td></tr><tr><td>90000000</td></tr><tr><td>32325190</td></tr><tr><td>60562200</td></tr><tr><td>65624000</td></tr> ...

-- %% [markdown]
-- ## <span style="font-size: 12pt; font-family: Montserrat, sans-serif; color: rgb(53, 74, 95); background-color: rgb(255, 255, 255); font-weight: 700; font-variant-numeric: normal; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Aggregate Your Friends and Code some SQL</span>
--
-- <span style="font-size: 10pt; font-family: Arvo, serif; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-numeric: normal; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Put together the following:</span>
--
-- 1. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">How many employees were reported in 2016 in all industries? Round to the nearest whole number.&nbsp; No chopping people into little bits, please.</span>

-- %%
--Using floor rounds down to the nearest whole number. sum adds them
SELECT FLOOR(SUM(value)) AS '2016 Total Employees '
FROM annual_2016
INNER JOIN series ON series.series_id=annual_2016.series_id --combines data from series and annual_2016
WHERE series.series_title = 'All employees' --filters for all employee

---2340612
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.115
-- <table><tr><th>2016 Total Employees </th></tr><tr><td>2340612</td></tr></table>

-- %% [markdown]
-- 2. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">How many women employees were reported in 2016 in all industries? Round to the nearest whole number.&nbsp;</span>

-- %%
--counts # women employees using series_id as a join method for annual_2016 and series
SELECT FLOOR(SUM(value)) AS '2016 Total Women Employees'
FROM annual_2016
INNER JOIN series ON series.series_id=annual_2016.series_id --combines data from series and annual_2016
WHERE series.series_title = 'women employees'

----1125489
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.158
-- <table><tr><th>2016 Total Women Employees</th></tr><tr><td>1125489</td></tr></table>

-- %% [markdown]
-- 3. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">How many production/nonsupervisory employees were reported in 2016? Round to the nearest whole number.&nbsp;</span>

-- %%
SELECT FLOOR(SUM(value)) AS '2016 Total Production/Nonsupervisory Employees'
FROM annual_2016
INNER JOIN series ON series.series_id=annual_2016.series_id --combines data from series and annual_2016
WHERE series.series_title = 'Production and nonsupervisory employees'
--1263649
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.130
-- <table><tr><th>2016 Total Production/Nonsupervisory Employees</th></tr><tr><td>1263649</td></tr></table>

-- %% [markdown]
-- 4. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">In January 2017, what is the average weekly hours worked by production and nonsupervisory employees across all industries?</span>

-- %%
--there is a january_2017 table, but not an annual 2017 table so I only have 1 month of data
SELECT FLOOR(AVG(value)) AS 'M1 2017 AVG Weekly Hours'
FROM january_2017
INNER JOIN series ON series.series_id=january_2017.series_id --combines data from series and annual_2017
WHERE series.series_title = 'Average weekly hours of production and nonsupervisory employees'
--36
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.239
-- <table><tr><th>M1 2017 AVG Weekly Hours</th></tr><tr><td>36</td></tr></table>

-- %% [markdown]
-- 5. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">What is the total weekly payroll for production and nonsupervisory employees across all industries in January 2017? Round to the nearest penny, please.</span>

-- %%
--series id and value in order to add 2017
SELECT ROUND(SUM(value),2) AS 'M1 2017 Total Weekly Payroll' --the 2 tells round to round to two decimal places
FROM january_2017
INNER JOIN series ON series.series_id=january_2017.series_id
WHERE series.series_title ='Average weekly earnings of all employees'
--3909716.87
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.141
-- <table><tr><th>M1 2017 Total Weekly Payroll</th></tr><tr><td>3909716.87</td></tr></table>

-- %% [markdown]
-- 6. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">In January 2017, which industry was the average weekly hours worked by production and nonsupervisory employees the highest? Which industry was the lowest?</span>

-- %%
--series id and value need MAX and MIN --needs work
SELECT industry.industry_name, MAX(january_2017.value)
FROM ((series
INNER JOIN industry ON industry.industry_code=series.industry_code)
INNER JOIN january_2017 ON january_2017.series_id=series.series_id)
WHERE series_title = 'Average weekly hours of production and nonsupervisory employees' 
GROUP BY january_2017.value, industry_name
ORDER BY january_2017.value DESC -- adding DESC will show the highest value by default the lowest is displayed

--Max Motor Vehicle power train components 49.8	Min Fitness and recreational sports Centers 16.7
-- Out:
-- (1056 rows affected)
-- Total execution time: 00:00:00.223
-- <table><tr><th>industry_name</th><th>(No column name)</th></tr><tr><td>Motor vehicle power train components</td><td>49.8</td></tr><tr><td>Motor vehicle power train components</td><td>49.4</td></tr><tr><td>NULL</td><td>47.4</td></tr><tr><td>Crushed and broken limestone mining</td><td>47.3</td></tr><tr><td>Support activities for mining</td><td>47.3</td></tr><tr><td>Stone mining and quarrying</td><td>47.2</td></tr><tr><td>Oil and gas pipeline construction</td><td>47.1</td></tr><tr><td>Support activities for mining</td><td>47.1</td></tr><tr><td>Motor vehicle metal stamping</td><td>46.8</td></tr><tr><td>Support activities for oil and gas operations</td><td>46.7</td></tr><tr><td>Coal mining</td><td>46.6</td></tr><tr><td>Motor vehicle metal stamping</td><td>46.6</td></tr><tr><td>Mining</td><td>46.3</td></tr><tr><td>Mining</td><td>46.1</td></tr><tr><td>Mining</td><td>45.9</td></tr><tr><td>NULL</td><td>45.8</td></tr><tr><td>Mining</td><td>45.8</td></tr><tr><td>Mining and logging</td><td>45.8</td></tr><tr><td>Boilers</td><td>45.7</td></tr><tr><td>Petroleum and coal products</td><td>45.6</td></tr><tr><td>Mining and logging</td><td>45.5</td></tr><tr><td>Waste treatment and disposal</td><td>45.2</td></tr><tr><td>Basic chemicals</td><td>45.1</td></tr><tr><td>Motor vehicles</td><td>45.1</td></tr><tr><td>Oil and gas pipeline construction</td><td>45.1</td></tr><tr><td>Petroleum and coal products</td><td>45.1</td></tr><tr><td>Waste treatment and disposal</td><td>45.1</td></tr><tr><td>Motor vehicle parts</td><td>44.7</td></tr><tr><td>Pipeline transportation</td><td>44.7</td></tr><tr><td>Basic chemicals</td><td>44.6</td></tr><tr><td>Motor vehicle parts</td><td>44.5</td></tr><tr><td>Power and communication system construction</td><td>44.5</td></tr><tr><td>Rubber products</td><td>44.5</td></tr><tr><td>Oil and gas extraction</td><td>44.4</td></tr><tr><td>Metal valves</td><td>44.3</td></tr><tr><td>Utility system construction</td><td>44.3</td></tr><tr><td>Other heavy construction</td><td>44.2</td></tr><tr><td>Rubber products</td><td>44.2</td></tr><tr><td>NULL</td><td>44.1</td></tr><tr><td>Crushed and broken limestone mining</td><td>44.1</td></tr><tr><td>Frozen food</td><td>44.1</td></tr><tr><td>Other specialized trucking</td><td>44.1</td></tr><tr><td>Surgical appliances and supplies</td><td>44.1</td></tr><tr><td>Turbine and power transmission equipment</td><td>44.1</td></tr><tr><td>All other motor vehicle parts</td><td>44</td></tr><tr><td>Cement and concrete products</td><td>44</td></tr><tr><td>Heavy and civil engineering construction</td><td>44</td></tr><tr><td>Metal valves</td><td>44</td></tr><tr><td>Motor vehicles</td><td>44</td></tr><tr><td>Transportation equipment</td><td>44</td></tr><tr><td>Turbine and power transmission equipment</td><td>44</td></tr><tr><td>NULL</td><td>43.9</td></tr><tr><td>All other motor vehicle parts</td><td>43.9</td></tr><tr><td>Highway</td><td>43.9</td></tr><tr><td>Power generation and supply</td><td>43.9</td></tr><tr><td>Pulp</td><td>43.9</td></tr><tr><td>Stone mining and quarrying</td><td>43.9</td></tr><tr><td>NULL</td><td>43.8</td></tr><tr><td>Corrugated and solid fiber boxes</td><td>43.8</td></tr><tr><td>Fossil fuel electric power generation</td><td>43.8</td></tr><tr><td>Motor vehicle gasoline engine and parts</td><td>43.8</td></tr><tr><td>Pipeline transportation</td><td>43.8</td></tr><tr><td>Electric power transmission and distribution</td><td>43.7</td></tr><tr><td>Transportation equipment</td><td>43.7</td></tr><tr><td>NULL</td><td>43.6</td></tr><tr><td>Electric power transmission and distribution</td><td>43.6</td></tr><tr><td>Pulp</td><td>43.6</td></tr><tr><td>Special tools</td><td>43.6</td></tr><tr><td>Aerospace products and parts</td><td>43.5</td></tr><tr><td>Animal slaughtering and processing</td><td>43.5</td></tr><tr><td>Frozen food</td><td>43.5</td></tr><tr><td>Industrial machinery</td><td>43.5</td></tr><tr><td>Motor vehicle gasoline engine and parts</td><td>43.5</td></tr><tr><td>NULL</td><td>43.4</td></tr><tr> ...

-- %% [markdown]
-- 7. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">In January 2021, which industry was the total weekly payroll for production and nonsupervisory employees the highest? Which industry was the lowest?</span>

-- %%
--there isn't data included in this for January 2021 so I am using January 2017
SELECT industry.industry_name, january_2017.value
FROM ((series
INNER JOIN industry ON industry.industry_code=series.industry_code)
INNER JOIN january_2017 ON january_2017.series_id=series.series_id)
WHERE series_title = 'Average weekly earnings of production and nonsupervisory employees' 
GROUP BY january_2017.value, industry_name
ORDER BY january_2017.value --adding DESC will sort by the highest value by default the lowest value is displayed
--MAX Reinsurance carriers 1847.47  MIN Bowling centers 97.33
-- Out:
-- (2202 rows affected)
-- Total execution time: 00:00:00.226
-- <table><tr><th>industry_name</th><th>value</th></tr><tr><td>Bowling centers</td><td>97.33</td></tr><tr><td>Family clothing stores</td><td>99.28</td></tr><tr><td>Bowling centers</td><td>100.17</td></tr><tr><td>Women's clothing stores</td><td>100.8</td></tr><tr><td>Fitness and recreational sports centers</td><td>102.84</td></tr><tr><td>Fitness and recreational sports centers</td><td>103.22</td></tr><tr><td>Limited-service restaurants</td><td>105.31</td></tr><tr><td>Family clothing stores</td><td>105.99</td></tr><tr><td>Women's clothing stores</td><td>106.02</td></tr><tr><td>Clothing stores</td><td>106.29</td></tr><tr><td>Limited-service restaurants</td><td>107.1</td></tr><tr><td>Snack and nonalcoholic beverage bars</td><td>109.61</td></tr><tr><td>Snack and nonalcoholic beverage bars</td><td>110</td></tr><tr><td>Clothing stores</td><td>110.97</td></tr><tr><td>Gift</td><td>113.87</td></tr><tr><td>Cafeterias</td><td>114.04</td></tr><tr><td>Civic and social organizations</td><td>114.48</td></tr><tr><td>Cafeterias</td><td>115.05</td></tr><tr><td>Civic and social organizations</td><td>115.54</td></tr><tr><td>Skiing facilities</td><td>116.8</td></tr><tr><td>Clothing accessories stores</td><td>117.46</td></tr><tr><td>Gift</td><td>118.02</td></tr><tr><td>Clothing accessories stores</td><td>120.26</td></tr><tr><td>Restaurants and other eating places</td><td>121.69</td></tr><tr><td>Drinking places</td><td>122.39</td></tr><tr><td>Florists</td><td>122.93</td></tr><tr><td>Drinking places</td><td>123.08</td></tr><tr><td>Clothing and clothing accessories stores</td><td>123.4</td></tr><tr><td>Restaurants and other eating places</td><td>123.86</td></tr><tr><td>Food services and drinking places</td><td>123.91</td></tr><tr><td>NULL</td><td>124.74</td></tr><tr><td>Food services and drinking places</td><td>125.81</td></tr><tr><td>Clothing and clothing accessories stores</td><td>126.7</td></tr><tr><td>Car washes</td><td>128.32</td></tr><tr><td>Book stores and news dealers</td><td>130.53</td></tr><tr><td>Accommodation and food services</td><td>131.18</td></tr><tr><td>Convenience stores</td><td>131.38</td></tr><tr><td>Florists</td><td>132.15</td></tr><tr><td>Convenience stores</td><td>132.25</td></tr><tr><td>Book stores and news dealers</td><td>132.59</td></tr><tr><td>Accommodation and food services</td><td>133.42</td></tr><tr><td>Amusements</td><td>133.51</td></tr><tr><td>NULL</td><td>134.42</td></tr><tr><td>Amusements</td><td>134.88</td></tr><tr><td>Leisure and hospitality</td><td>135.32</td></tr><tr><td>Skiing facilities</td><td>135.51</td></tr><tr><td>Full-service restaurants</td><td>136.59</td></tr><tr><td>Leisure and hospitality</td><td>136.92</td></tr><tr><td>Car washes</td><td>137.06</td></tr><tr><td>RV parks and recreational camps</td><td>137.7</td></tr><tr><td>Beer</td><td>138.19</td></tr><tr><td>Coin-operated laundries and drycleaners</td><td>139.04</td></tr><tr><td>Full-service restaurants</td><td>139.53</td></tr><tr><td>Coin-operated laundries and drycleaners</td><td>139.55</td></tr><tr><td>Beer</td><td>139.66</td></tr><tr><td>Gasoline stations with convenience stores</td><td>141.19</td></tr><tr><td>Gasoline stations with convenience stores</td><td>142.28</td></tr><tr><td>Specialty food stores</td><td>142.92</td></tr><tr><td>Specialty food stores</td><td>143.21</td></tr><tr><td>Other home furnishings stores</td><td>143.32</td></tr><tr><td>Janitorial services</td><td>143.51</td></tr><tr><td>Janitorial services</td><td>143.94</td></tr><tr><td>Pet care services</td><td>144.8</td></tr><tr><td>Gasoline stations</td><td>145.28</td></tr><tr><td>Other home furnishings stores</td><td>145.66</td></tr><tr><td>Gasoline stations</td><td>145.77</td></tr><tr><td>Drycleaning and laundry services</td><td>146.58</td></tr><tr><td>RV parks and recreational camps</td><td>147.9</td></tr><tr><td>Pet care services</td><td>149.39</td></tr><tr><td>Special food services</td><td>149.42</td></tr><tr><td>Drycleaning and laundry services</td><td>149.94</td></tr><tr><td>S ...

-- %% [markdown]
-- ## <span style="font-size: 12pt; font-family: Montserrat, sans-serif; color: rgb(53, 74, 95); background-color: rgb(255, 255, 255); font-weight: 700; font-variant-numeric: normal; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Subqueries, Unions, Derived Tables, Oh My!</span>
--
-- 1. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">Write a query that returns the series_id, industry_code, industry_name, and value from the january_2017 table but only if that value is greater than the average value for annual_2016 of data_type_code 82.</span>

-- %%
--work in progress
SELECT series.series_id, industry.industry_code, industry.industry_name, january_2017.value AS '2017 value', annual_2016.value AS '2016 value'
FROM series(((
INNER JOIN industry ON industry.industry_code=series.industry_code)
INNER JOIN january_2017 ON january_2017.series_id=series.series_id)
INNER JOIN annual_2016 ON annual_2016.series_id=series.series_id)
WHERE january_2017.value < AVG(annual_2016.data_type_code = 82)
-- Out:
-- : Msg 156, Level 15, State 1, Line 4
-- Incorrect syntax near the keyword 'INNER'.
-- Total execution time: 00:00:00.049

-- %% [markdown]
-- 2. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">Create a Union table comparing average weekly earnings&nbsp; of production and nonsupervisory employees between annual_16 and january_17 using the data type 30.&nbsp; Round to the nearest penny.&nbsp; You should have a column for the average earnings and a column for the year, and the period.</span>

-- %% [markdown]
-- ## <span style="font-size:12pt;font-family:Montserrat, sans-serif;color:rgb(53, 74, 95);background-color:rgb(255, 255, 255);font-weight:700;vertical-align:baseline;white-space:pre-wrap;">Summarize Your Results</span>
--
-- <span style="font-size:10pt;font-family:Arvo, serif;color:rgb(102, 102, 102);background-color:rgb(255, 255, 255);vertical-align:baseline;white-space:pre-wrap;">With what you know now about the </span> <span style="background-color:rgb(255, 255, 255);color:rgb(102, 102, 102);font-family:&quot;Times New Roman&quot;;font-size:13.3333px;white-space:pre-wrap;">Bureau of Labor Statistics (BLS) Current Employment Survey (CES) results and working with the</span> <span style="color:rgb(102, 102, 102);white-space:pre-wrap;font-family:&quot;Times New Roman&quot;;font-size:13.3333px;">Labor Statistics Database</span><span style="background-color:rgb(255, 255, 255);color:rgb(102, 102, 102);font-family:Arvo, serif;font-size:10pt;white-space:pre-wrap;">, answer the following questions. Note that while this is subjective, you should include relevant data to back up your opinion.</span>
--
-- 1. <span style="background-color:rgb(255, 255, 255);font-size:10pt;white-space:pre-wrap;color:rgb(102, 102, 102);font-family:Arvo, serif;">During which time period did production and nonsupervisory employees fare better?</span>

-- %% [markdown]
-- Double click here to add your answer

-- %% [markdown]
-- 2. <span style="background-color: rgb(255, 255, 255); font-size: 10pt; white-space: pre-wrap; color: rgb(102, 102, 102); font-family: Arvo, serif;">In which industries did production and nonsupervisory employees fare better? Fitness and recreatioanl centers. They wokred the least weekly hours and made the most</span>

-- %% [markdown]
-- Double click here to add your answer.

-- %% [markdown]
-- 3. <span style="font-size: 10pt; font-family: Arvo, serif; color: rgb(102, 102, 102); background-color: rgb(255, 255, 255); font-variant-numeric: normal; font-variant-east-asian: normal; vertical-align: baseline; white-space: pre-wrap;">Now that you have explored the datasets, is there any data or information that you wish you had in this analysis?</span>
--
-- <span style="font-size: 13.3333px; white-space: pre-wrap;">some of the series_id data is Null. I'd like to know why</span>

-- %% [markdown]
-- Double click here to add your answer.
